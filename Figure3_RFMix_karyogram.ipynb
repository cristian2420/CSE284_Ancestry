# %%
# %%bash
#
# for SAMPLE in 'HG01173'; do
#     echo $SAMPLE
#     haptools karyogram \
#         --bp ./results/${SAMPLE}_rfmix.bp \
#         --sample ${SAMPLE} --out ./results/rfmix_${SAMPLE}.png \
#         --title ${SAMPLE} \
#         --colors "EUR:blue,AFR:red,EAS:green,SAS:purple"
# done
# Out:
# HG01173
# [    INFO] Generating Karyogram... (__main__.py:84)
# [    INFO] Collecting Haplotype Blocks... (karyogram.py:246)
# [    INFO] Karyogram Complete! Saved to ./results/rfmix_HG01173.png (karyogram.py:308)

# %%
from IPython.display import Image
Image(filename='./results/rfmix_HG01173.png')
